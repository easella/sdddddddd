# %%
# !pip install pytubefix
# !pip install scrapetube
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 730.7/730.7 kB 17.7 MB/s eta 0:00:0000:01
# ...

# %%
# !pip install lightgbm

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import CategoricalNB
from sklearn.multioutput import ClassifierChain
from sklearn.naive_bayes import ComplementNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.dummy import DummyClassifier
from sklearn.tree import ExtraTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.semi_supervised import LabelPropagation
from sklearn.semi_supervised import LabelSpreading
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegressionCV
from sklearn.neural_network import MLPClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import NearestCentroid
from sklearn.svm import NuSVC
from sklearn.multiclass import OneVsOneClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.multiclass import OutputCodeClassifier
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.linear_model import Perceptron
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.neighbors import RadiusNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import RidgeClassifier
from sklearn.linear_model import RidgeClassifierCV
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.utils import all_estimators


estimators = all_estimators(type_filter='classifier')
classification_estimators = []
i = 1
for name, class_ in estimators:
    classification_estimators.append(class_.__name__)

# %%
from sklearn.base import is_classifier, is_regressor
import pandas as pd

dat = []

# %%
is_regressor(

# %%
x=0
z=""
while x<41:
    z+="x"+str(x)+"prob+"
    x+=1
z

# %%
x=0
for c in classification_estimators:
    c = eval(c)
    if(is_regressor(c)==True):
        
        print("    prob=x"+str(x)+".predict_proba(er)")
        print("    prob=str(prob)")
        print("    prob=prob.replace('[','')")
        print("    prob=prob.replace(']','')")
        print("    prob=prob.split(' ')[0]")
        print("    x"+str(x)+"prob=float(prob)")
        x+=1
    else:
        print("    prob=x"+str(x)+".predict_proba(er)")
        print("    prob=str(prob)")
        print("    prob=prob.replace('[','')")
        print("    prob=prob.replace(']','')")
        print("    prob=prob.split(' ')[0]")
        print("    x"+str(x)+"prob=float(prob)")
        x+=1

# %%
# !pip install lightgbm
# !pip install xgboost
# !pip install scikit-learn

# %%
row
# Out:
# Pandas(Index=0, season=2023.0, rk='1', team='Houston', conf=3.0, G='34', Rec='30–4', CREC='19–1', ADJOE='124.67', ADJDE='87.61', BARTHAG='.98301', EFG='52.788', EFGD='44.94', TOR='14.625', TORD='21.717', ORB='36.115', DRB='29.3157', FTR='28.2315', FTRD='34.1211', _19='49.0267', _20='43.95', _21='39.82', _22='30.933', _23='34.5296', _24='43.1306', ADJT='62.2360', WAB=11.62, q1w=14, q2w=8, q3w=4, q4w=4, q1l=4, q2l=0, q3l=0, q4l=0, hw=16, hl=1, aw=14, al=3)

# %%
import pandas as pd
df=pd.read_csv("https://ontheroadtovote.com/bartz.csv")
df=df[df.season!=2019]
import os
h=0
from sklearn.linear_model import LinearRegression 
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
logr = LogisticRegression()
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
import lightgbm as lgb
lin=LinearRegression()
from lightgbm import LGBMClassifier
rfc=RandomForestClassifier()
dtc=DecisionTreeClassifier()
x=[]
y=[]
cs={}
dfw=pd.read_csv("https://ontheroadtovote.com/alarge.csv")
dfw=dfw[dfw.Year>2006]
dfw=dfw[dfw.TY==1]
dfw=dfw.replace("Louisiana State","LSU")
dfw=dfw.replace("Loyola (MD)","Loyola MD")
dfw=dfw.replace("Fairleigh-Dickinson","FDU")
dfw=dfw.replace("Fairleigh Dickinson","FDU")
dfw=dfw.replace("Southern California","USC")
dfw=dfw.replace("Miami (FL)","Miami FL")
dfw=dfw.replace("Brigham Young","BYU")
dfw=dfw.replace("St. John's (NY)","St. John's")
dfw=dfw.replace("Nevada-Las Vegas","UNLV")
dfw=dfw.replace("Saint Mary's (CA)","Saint Mary's")
dfw=dfw.replace("Virginia Commonwealth","VCU")
dfw=dfw.replace("Southern Mississippi","Southern Miss")
dfw=dfw.replace("NC State","N.C. State")
te=set(dfw.Team.tolist())
sr={}

    
df['team']=df['team'].str.replace(" St."," State")
for row in df.itertuples():
    if r"\xa0" in str(row):
        h+=1
        yt=str(row.team)
        yt=yt.split("\xa0")[0]
        df.at[row.Index,'team']=yt
for row in dfw.itertuples():
    if float(row.Year) not in sr:
        sr[float(row.Year)]={}
    sr[float(row.Year)][str(row.Team)]=float(row.TY)
for row in df.itertuples():
    if row.team in sr[float(row.season)]:
        df.at[row.Index,'alarge']=1
    else:
        df.at[row.Index,'alarge']=0
u=0
for conf in set(df.conf.tolist()):
    cs[conf]=u
    u+=1
for row in df.itertuples():
    df.at[row.Index,'conf']=float(cs[row.conf])
df=df.replace("–","-")

df=df.astype({"Rec":"string"})
df["Rec"]=df['Rec'].str.replace("–","-")
df['netw']=df['netw'].fillna(0)
df['netl']=df['netl'].fillna(0)
for row in df.itertuples():
    rec=str(row.Rec)
    rec=rec.replace("-"," ")
    w=str(rec).split(" ")[0]
    l=str(rec).split(" ")[1]
    w=float(row.q1w)+float(row.q2w)+float(row.q3w)+float(row.q4w)
    l=float(row.q1l)+float(row.q2l)+float(row.q3l)+float(row.q4l)
    w=float(w)
    l=float(l)
    pct=1/(w+l)*w
    net=float(row.netw)+float(row.netl)
    net=net/2
    if float(row.netw)==0:
        sos=float(row.netl)
    elif float(row.netl)==0:
        sos=float(row.netw)
    else:
        sos=float(row.netw)+float(row.netl)
        sos=sos/2
    if ((float(row.q1w)+float(row.q2w)+float(row.q3w)+float(row.q4w))==0):
        pty=0
    else:
        pty=1/(float(row.q1w)+float(row.q2w)+float(row.q3w)+float(row.q4w))
    q1wpct=pty*float(row.q1w)
    q2wpct=pty*float(row.q2w)
    q3wpct=pty*float(row.q3w)
    q4wpct=pty*float(row.q4w)
    if (float(row.hw)+float(row.hl))==0:
        hwpct=0
    else:
        hwpct=1/(float(row.hw)+float(row.hl))
    hwpct=hwpct*float(row.hw)
    if (float(row.aw)+float(row.al))==0:
        awpct=0
    else:
        awpct=1/(float(row.aw)+float(row.al))
    awpct=awpct*float(row.aw)
    k=[float(row.rk),float(row.conf),float(row.BARTHAG),float(row.WAB),float(pct),float(sos),q1wpct,q2wpct,q3wpct,q4wpct,hwpct,awpct]
    x.append(k)
    y.append(float(row[44]))
print("done training")
import xgboost as xgb
xgb = xgb.XGBRegressor(objective="reg:linear", random_state=42)

xgb.fit(x, y)
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import ElasticNet
print("1")
en=ElasticNet(random_state=42).fit(x,y)
print("1")
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor(random_state=42).fit(x,y)
print("1")
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.kernel_ridge import KernelRidge
from lightgbm import LGBMRegressor
kr=KernelRidge(2).fit(x,y)
print("1")
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier

x5 = AdaBoostClassifier(random_state=42).fit(x,y)
print("1")

x1=GaussianNB().fit(x,y)
print("1")
from sklearn.neighbors import KNeighborsClassifier 
x2 = KNeighborsClassifier().fit(x,y)
print("1")
x3=LogisticRegression(random_state=42).fit(x,y)
print("1")
from sklearn.naive_bayes import MultinomialNB
x13=RandomForestRegressor(random_state=42).fit(x,y)
print("1")
rfg=RandomForestRegressor(random_state=42).fit(x,y)
print("1")
from sklearn.svm import LinearSVC
x11=LinearSVC(random_state=42).fit(x,y)
print("1")
gbr=GradientBoostingClassifier(random_state=None).fit(x,y)
print("1")
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegressionCV
x10=LogisticRegressionCV(random_state=42).fit(x,y)
print("1")
tree = DecisionTreeClassifier(max_depth=5,random_state=42).fit(x,y)
print("1")
arrp=[]
import requests
from bs4 import BeautifulSoup
x0=RandomForestClassifier(random_state=42).fit(x,y)
print("1")
x4=LinearRegression().fit(x,y)
print("1")
import numpy as np
from sklearn.linear_model import BayesianRidge
bay=BayesianRidge().fit(x,y)
print("1")
model = LGBMClassifier(metric='auc',random_state=42).fit(x,y)
print("done models")
s=2024
if 1==1:
    url="https://barttorvik.com/trank.php?begin="+str("20241104")+"&end="+str("20250316")+"&conlimit=All&year=2025&top=0&hteam=&quad=5&rpi="
    html=requests.get(url).text
    soup=BeautifulSoup(html)
    table=soup.find_all("table")[0]
    rks={}
    for tr in table.find_all("tr"):
        if "seedrow" in str(tr):
            team=tr.find_all("td")[1].text
            team=team.split("\xa0")[0]
            team=team.replace("amp;","")
            rks[team]=float(tr.find_all("td")[0].text)
    for tr in table.find_all("tr"):
        if "seedrow" in str(tr):
            tds=tr.find_all("td")
            row=[]
            row.append(float(s)-1)
            res=tds[4].find("a")
            res=str(res)
            wins=res.split("Wins:&lt;/b&gt;")[1]
            wins=wins.replace(", &lt;br/&gt;&lt;b&gt;","")
            wins=wins.split("Losses&lt;/b&gt;:")[0]
            wins=wins.split(">")[0]
            
            losses=res.split("Losses&lt;/b&gt;:")[1]
            losses=losses.replace(', "',"")
            wins=wins.split(">")[0]
            wins=wins.replace("&lt;br/&gt;&lt;b&gt;","")
            losses=losses.replace("&lt;br/&gt;&lt;b&gt;","")
            if ' ">' in str(wins):
                wins=wins.split(' ">')[0]
            if ' ">' in str(losses):
                losses=losses.split(' ">')[0]
            q1w=0
            q1l=0
            q2w=0
            q2l=0
            q3w=0
            q3l=0
            hw=0
            hl=0
            aw=0
            al=0
            nw=0
            netw=[]
            netl=[]
            nl=0
            q4w=0
            q4l=0
            if wins!=' ' and wins!='':
                
                
                for w in wins.split(","):
                    wz=w
                    w=w.replace("amp;","")
                    w=w.rstrip()
                    w=w.lstrip()
                    t=w.replace("v. ","")
                    t=t.replace(" @","")
                    t=t.replace("@ ","")
                    if ">" in t:
                        t=t.split(">")[0]
                    if ">" in w:
                        w=w.split(">")[0]
                    netw.append(rks[t])
                    if "@" in str(w):
                        aw+=1
                    if ("@ ") in str(w):
                        w=w.replace("@ ","")
                        if rks[w]<76:
                            q1w+=1
                        elif rks[w]<136:
                            q2w+=1
                        elif rks[w]<241:
                            q3w+=1
                        else:
                            q4w+=1
                    if "@" not in str(wz) and "v." not in str(w):
                        hw+=1
                        if rks[w]<31:
                            q1w+=1
                        elif rks[w]<76:
                            q2w+=1
                        elif rks[w]<161:
                            q3w+=1
                        else:
                            q4w+=1
                    if "v." in str(w):
                        nw+=1
                        w=w.replace("v. ","")
                        if rks[w]<51:
                            q1w+=1
                        elif rks[w]<101:
                            q2w+=1
                        elif rks[w]<201:
                            q3w+=1
                        else:
                            q4w+=1
            if losses!=' ' and losses!='':
                for w in losses.split(","):
                    wz=w
                    w=w.replace("amp;","")
                    w=w.rstrip()
                    w=w.lstrip()
                    t=w.replace("v. ","")
                    t=t.replace(" @","")
                    t=t.replace("@ ","")
                    if ">" in w:
                        w=w.split(">")[0]
                    if ">" in t:
                        t=t.split(">")[0]
                    netl.append(rks[t])
                    if "@" in str(w):
                        al+=1
                        if ("@") in str(w):
                            w=w.replace("@ ","")
                        if rks[w]<76:
                            q1l+=1
                        elif rks[w]<136:
                            q2l+=1
                        elif rks[w]<241:
                            q3l+=1
                        else:
                            q4l+=1
                    if "@" not in str(wz) and "v." not in str(w):
                        hl+=1
                        if (" @ ") in str(w):
                            w=w.replace("   ","")
                        if rks[w]<31:
                            q1l+=1
                        elif rks[w]<76:
                            q2l+=1
                        elif rks[w]<161:
                            q3l+=1
                        else:
                            q4l+=1
                    if "v." in str(w):
                        nl+=1
                        if ("v. ") in str(w):
                            w=w.replace("v. ","")
                        if rks[w]<51:
                            q1l+=1
                        elif rks[w]<101:
                            q2l+=1
                        elif rks[w]<201:
                            q3l+=1
                        else:
                            q4l+=1
            for i in range(0,len(tds)):
                if i==4:
                    y=tds[i].find("a").text
                    x=tds[i].find("span").text
                    row.append(y)
                    row.append(x)
                else:
                    row.append(tds[i].text)
            
            row.append(q1w)
            row.append(q2w)
            row.append(q3w)
            row.append(q4w)
            row.append(q1l)
            row.append(q2l)
            row.append(q3l)
            row.append(q4l)
            row.append(hw)
            row.append(hl)
            row.append(aw+nw)
            row.append(al+nl)
            row.append(np.mean(netw))
            row.append(np.mean(netl))
            arrp.append(row)
            
dfe=pd.DataFrame(arrp,columns=['season','rk','team','conf','G','Rec',"CREC","ADJOE","ADJDE","BARTHAG","EFG","EFGD","TOR","TORD","ORB","DRB","FTR","FTRD","2P","2PD","3P","3PD","3PR","3PRD","ADJT","WAB","q1w",'q2w','q3w','q4w','q1l','q2l','q3l','q4l','hw','hl','aw','al','netw','netl'])
cs={}
dfe=dfe.astype({"WAB":"string"})
dfe['WAB']=dfe['WAB'].str.replace("+","")
dfe=dfe.astype({"WAB":float})
u=0
for row in dfe.itertuples():
    team=str(row.team)
    if "\xa0" in str(team):
        team=team.split("\xa0")[0]
        dfe.at[row.Index,"team"]=team
for row in dfe.itertuples():
    if 'vs' in str(row.team):
        se=str(row.team).split("   vs")[0]
        dfe.at[row.Index,'team']=se
for conf in set(dfe.conf.tolist()):
    cs[conf]=u
    u+=1
for row in dfe.itertuples():
    dfe.at[row.Index,'conf']=float(cs[row.conf])
dfe=dfe.fillna(0)
dfe=dfe[dfe.FTR!=0]
pct={}
votes=[]
for row in dfe.itertuples():
    t=str(row.team)
    t=t.split("\xa0\xa0\xa0vs")[0]
    dfe.at[row.Index,'team']=t
votes=[]
pcts={}
yw=0
for i in range(0,12):
    pcts[str(i)]={}
for row in dfe.itertuples():
    rec=str(row.Rec)
    rec=rec.replace("–"," ")
    w=str(rec).split(" ")[0]
    l=str(rec).split(" ")[1]
    w=float(row.q1w)+float(row.q2w)+float(row.q3w)+float(row.q4w)
    l=float(row.q1l)+float(row.q2l)+float(row.q3l)+float(row.q4l)
    pctz=1/(w+l)*w
    if float(row.netw)==0:
        sos=float(row.netl)
    elif float(row.netl)==0:
        sos=float(row.netw)
    else:
        sos=float(row.netw)+float(row.netl)
        sos=sos/2
    if ((float(row.q1w)+float(row.q2w)+float(row.q3w)+float(row.q4w))==0):
        pty=0
    else:
        pty=1/(float(row.q1w)+float(row.q2w)+float(row.q3w)+float(row.q4w))
    q1wpct=pty*float(row.q1w)
    q2wpct=pty*float(row.q2w)
    q3wpct=pty*float(row.q3w)
    q4wpct=pty*float(row.q4w)
    if (float(row.hw)+float(row.hl))==0:
        hwpct=0
    else:
        hwpct=1/(float(row.hw)+float(row.hl))
    hwpct=hwpct*float(row.hw)
    if (float(row.aw)+float(row.al))==0:
        awpct=0
    else:
        awpct=1/(float(row.aw)+float(row.al))
    awpct=awpct*float(row.aw)
    k=[float(row.rk),float(row.conf),float(row.BARTHAG),float(row.WAB),pctz,sos,q1wpct,q2wpct,q3wpct,q4wpct,hwpct,awpct]
    er=np.array(k).reshape(1,-1)
    prob=x0.predict_proba(er)
    prob=str(prob)
    prob=prob.replace('[','')
    prob=prob.replace(']','')
    prob=prob.split(' ')[1]
    x0prob=float(prob)
    prob=x1.predict_proba(er)
    prob=str(prob)
    prob=prob.replace('[','')
    prob=prob.replace(']','')
    prob=prob.split(' ')[1]
    x1prob=float(prob)
    prob=x2.predict_proba(er)
    prob=str(prob)
    prob=prob.replace('[','')
    prob=prob.replace(']','')
    prob=prob.split(' ')[1]
    x2prob=float(prob)
    prob=x3.predict_proba(er)
    prob=str(prob)
    prob=prob.replace('[','')
    prob=prob.replace(']','')
    prob=prob.split(' ')[1]
    x3prob=float(prob)
    prob=x4.predict(er)
    prob=str(prob)
    prob=prob.replace('[','')
    prob=prob.replace(']','')
    x4prob=float(prob)
    prob=x5.predict_proba(er)
    prob=str(prob)
    prob=prob.replace('[','')
    prob=prob.replace(']','')
    prob=prob.split(' ')[1]
    x5prob=float(prob)
    prob=tree.predict_proba(er)
    prob=str(prob)
    prob=prob.replace('[','')
    prob=prob.replace(']','')
    prob=prob.split(' ')[1]
    treeprob=float(prob)
    prob=model.predict_proba(er)
    prob=str(prob)
    prob=prob.replace('[','')
    prob=prob.replace(']','')
    prob=prob.split(' ')[1]
    gbmprob=float(prob)
    prob=xgb.predict(er)
    prob=str(prob)
    prob=prob.replace('[','')
    prob=prob.replace(']','')
    xgbprob=float(prob)
    prob=x11.predict(er)
    prob=str(prob)
    prob=prob.replace('[','')
    prob=prob.replace(']','')
    x11prob=float(prob)
    prob=model.predict_proba(er)
    prob=str(prob)
    prob=prob.replace('[','')
    prob=prob.replace(']','')
    prob=prob.split(' ')[1]
    x12prob=float(prob)
    prob=x13.predict(er)
    prob=str(prob)
    prob=prob.replace('[','')
    prob=prob.replace(']','')
    x13prob=float(prob)
    pcts['0'][row.team]=x0prob
    pcts['1'][row.team]=x1prob
    pcts['2'][row.team]=x2prob
    pcts['3'][row.team]=x3prob
    pcts['4'][row.team]=x4prob
    pcts['5'][row.team]=x5prob
    pcts['6'][row.team]=treeprob
    pcts['7'][row.team]=gbmprob
    pcts['8'][row.team]=xgbprob
    pcts['9'][row.team]=x12prob
    pcts['10'][row.team]=x11prob
    pcts['11'][row.team]=x13prob
# Out:
# done training
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [19:48:36] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 1
# 1
# 1
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...

# %%
row
# Out:
# Pandas(Index=363, season=2023.0, rk='364', team='Mississippi Valley St.', conf=10.0, G='29', Rec='1–28', CREC='1–17', ADJOE='83.2364', ADJDE='125.4364', BARTHAG='.0089364', EFG='42.1364', EFGD='57.9363', TOR='24.3363', TORD='15.0315', ORB='22.7343', DRB='38.0361', FTR='30.3266', FTRD='38.4304', _19='41.6363', _20='58.8363', _21='28.8356', _22='37.7351', _23='30.6344', _24='38.4162', ADJT='65.5307', WAB=-21.0355, q1w=0, q2w=0, q3w=0, q4w=1, q1l=8, q2l=1, q3l=1, q4l=18, hw=0, hl=9, aw=1, al=19, netw=362.0, netl=216.75)

# %%
aqs=["Grand Canyon","St. John's","Gonzaga","UC San Diego","VCU","Akron","Troy","Omaha","SIUE","Montana","Michigan","Houston","Memphis","Mount St. Mary's","American","St. Francis (PA)","Drake","Florida","Bryant","Wofford","Robert Morris","McNeese St.","Duke","Lipscomb","High Point","Liberty","UNC Wilmington","Yale","Norfolk State","Alabama State","Colorado St."]
tz=set(pcts['0'])
ptz=pcts
numcons={}
for row in dfe.itertuples():
    numcons[row.team]=0
for key in ptz:
    for t in ptz[key]:
        if float(pcts[key][t])>0.10:
            if t not in aqs:
                numcons[t]+=1
for key in ptz:
    for team in ptz[key].copy():
        if team in aqs:
            ptz[key].pop(team)
for key in ptz:
    ptz[key]=sorted(ptz[key],key=ptz[key].get,reverse=True)
    ptz[key]=ptz[key][:24]
numvotes={}

for row in dfe.itertuples():
    numvotes[row.team]=0
for key in ptz:
    for team in ptz[key]:
        numvotes[team]+=1
atlarge=[]
for team in numvotes:
    if numvotes[team]>8:
        atlarge.append(team)
cons=[]
for t in tz:
    if t not in atlarge and t not in aqs:
        if numcons[t]>3 or numvotes[t]>3:
            if t not in atlarge:
                cons.append(t)

# %%
row
# Out:
# Pandas(Index=655, _1=655, season=2008.0, rk=315, team='SIU Edwardsville', conf=0.0, G=15, Rec='3-12', CREC='0–0', ADJOE=86.0338, ADJDE=101.5184, BARTHAG=0.1301315, EFG=45.0309, EFGD=51.3266, TOR=23.5304, TORD=19.5236, ORB=19.7343, DRB=36.0293, FTR=29.9316, FTRD=41.4275, _20=43.1317, _21=50.1256, _22=32.5235, _23=36.8298, _24=33.2161, _25=24.41, ADJT=73.113, WAB=-7.516, q1w=0, q2w=0, q3w=0, q4w=3, q1l=2, q2l=3, q3l=7, q4l=0, hw=0, hl=0, aw=2, al=11, nw=1, nl=1, netw=285.3333333333333, netl=132.16666666666666, alarge=0.0)

# %%
jk=[]
import numpy as np
for key in pcts:
    jk.append(pcts[key]['UC San Diego'])
np.mean(jk)
# Out:
# 0.2203474108333334

# %%
a=dfe[dfe.team=='UC San Diego']
for g in a.itertuples():
    print(g)
# Out:
# Pandas(Index=50, season=2023.0, rk='51', team='UC San Diego', conf=23.0, G='32', Rec='28–4', CREC='18–2', ADJOE='112.770', ADJDE='97.538', BARTHAG='.842351', EFG='55.431', EFGD='47.742', TOR='13.46', TORD='23.32', ORB='25.6307', DRB='28.4102', FTR='33.8153', FTRD='29.893', _19='56.130', _20='46.220', _21='36.553', _22='33.1127', _23='49.68', _24='44.3328', ADJT='66.5263', WAB=1.244, q1w=1, q2w=3, q3w=8, q4w=16, q1l=1, q2l=0, q3l=3, q4l=0, hw=11, hl=2, aw=17, al=2, netw=209.75, netl=105.5)

# %%
rte={}
for i in range(1,15):
    rte[str(i)]=i
rte=sorted(rte,key=rte.get,reverse=True)
len(rte[:8])
# Out:
# 8

# %%
tz=set(pcts['0'])
for t in tz:
    if t not in atlarge and t not in aqs:
        if numcons[t]>3 or numvotes[t]>3:
            if t not in atlarge:
                cons.append(t)

# %%
pt={}
for i in range(0,12):
    pt[str(i)]={}
for row in dfe.itertuples():
    for i in range(0,12):
        if row.team in cons and row.team not in aqs and row.team not in atlarge:
            pt[str(i)][row.team]=float(pcts[str(i)][row.team])        
nvs={}
for row in dfe.itertuples():
    if row.team in cons and row.team not in aqs and row.team not in atlarge:
        nvs[row.team]=0
for key in pt:
    af=pt[key]
    af=sorted(af,key=af.get,reverse=True)
    af=af[:8]
    for t in af:
        nvs[t]+=1
while len(atlarge)<45:
    pt={}
    for i in range(0,12):
        pt[str(i)]={}
    for row in dfe.itertuples():
        for i in range(0,12):
            
            if row.team in cons and row.team not in aqs and row.team not in atlarge:
                pt[str(i)][row.team]=float(pcts[str(i)][row.team]) 
    if len(nvs)>19:
        for key in pt:
            pt[key]=sorted(pt[key],key=pt[key].get,reverse=True)
            pt[key]=pt[key][:8]
    if len(nvs)>13 and len(nvs)<20:
        for key in pt:
            pt[key]=sorted(pt[key],key=pt[key].get,reverse=True)
            pt[key]=pt[key][:6]
    if len(nvs)<14:
        for key in pt:
            pt[key]=sorted(pt[key],key=pt[key].get,reverse=True)
            pt[key]=pt[key][:4]
    
    numvotes={}
    for row in dfe.itertuples():
        if row.team not in aqs and row.team not in atlarge and row.team in cons:
            numvotes[row.team]=0
    for key in pt:
        for team in pt[key]:
            numvotes[team]+=1
    voted=sorted(numvotes,key=numvotes.get,reverse=True)
    voted=voted[:4]
    for t in voted:
        cons.remove(t)
        atlarge.append(t)

# %%
atlarge[:37]
# Out:
# ['Alabama',
#  'Tennessee',
#  'Texas Tech',
#  'Iowa St.',
#  'Arizona',
#  'Maryland',
#  'Wisconsin',
#  'BYU',
#  'Kentucky',
#  'Kansas',
#  'Illinois',
#  'Purdue',
#  'Missouri',
#  'Texas A&M',
#  'UCLA',
#  'Marquette',
#  'Baylor',
#  'Mississippi',
#  'Mississippi St.',
#  'Creighton',
#  'Oregon',
#  'Connecticut',
#  'Louisville',
#  'Georgia',
#  'West Virginia',
#  'North Carolina',
#  'New Mexico',
#  'Oklahoma',
#  'Arkansas',
#  'Michigan St.',
#  'Clemson',
#  'Vanderbilt',
#  'Xavier',
#  'Auburn',
#  "Saint Mary's",
#  'Utah St.',
#  'Texas']

# %%
atlarge[37:]
# Out:
# ['Boise St.',
#  'San Diego St.',
#  'Indiana',
#  'Ohio St.',
#  'Cincinnati',
#  'SMU',
#  'Wake Forest',
#  'San Francisco']

# %%
atlarge[37:]
# Out:
# ['SMU',
#  'San Diego St.',
#  'Boise St.',
#  'Indiana',
#  'Cincinnati',
#  'Villanova',
#  'Wake Forest',
#  'Ohio St.',
#  'Santa Clara',
#  'Nebraska',
#  'San Francisco']

# %%
y=[]
for team in atlarge:
    team=str(team)
    if "\xa0" in str(team):
        team=team.split("\xa0")[0]
        y.append(team)

# %%
"Auburn" in str(atlarge)
# Out:
# True

# %%
atlarge[37:]
# Out:
# ['Texas',
#  'Boise St.',
#  'Utah St.',
#  'SMU',
#  'Cincinnati',
#  'Nebraska',
#  'Wake Forest',
#  'Ohio St.']

# %%
import numpy as np
jk=[]
for y in pcts:
    jk.append(pcts[y]['Liberty'])
np.mean(jk)

# %%
atlarge[:37]

# %%
atlarge

# %%
voted=sorted(numvotes,key=numvotes.get,reverse=True)
voted

# %%
ptzz=pcts

# %%
cons=[]
for t in pcts['0']:
    if t not in atlarge and t not in aqs:
        if numcons[t]>3 or numvotes[t]>3:
            if t not in atlarge:
                cons.append(t)

# %%
cons

# %%
pctz=sorted(pct,key=pct.get,reverse=True)
aqs=["St. John's","Gonzaga","Troy","Omaha","SIUE","Northern Colorado","Michigan St.","Houston","Memphis","Merrimack","Navy","St. Francis (PA)","UC San Diego","Drake","Auburn","Maine","Wofford","Robert Morris","McNeese St.","Duke","Lipscomb","High Point","Liberty","UNC Wilmington","Yale","Norfolk State","Jackson State","Utah St."]
h=0
ts=[]
for y in aqs:
    ts.append(y)
for g in pctz:
    if len(ts)<100:
        if g not in ts:
            ts.append(g)

# %%
ts[65]

# %%
ts[65]

# %%
!

# %%
dfw=pd.read_csv("https://ontheroadtovote.com/alarge.csv")
dfw=dfw[dfw.Year>2006]
dfw=dfw[dfw.TY==1]
dfw=dfw.replace("Louisiana State","LSU")
dfw=dfw.replace("Loyola (MD)","Loyola MD")
dfw=dfw.replace("Fairleigh-Dickinson","FDU")
dfw=dfw.replace("Fairleigh Dickinson","FDU")
dfw=dfw.replace("Southern California","USC")
dfw=dfw.replace("Miami (FL)","Miami FL")
dfw=dfw.replace("Brigham Young","BYU")
dfw=dfw.replace("St. John's (NY)","St. John's")
dfw=dfw.replace("Nevada-Las Vegas","UNLV")
dfw=dfw.replace("Saint Mary's (CA)","Saint Mary's")
dfw=dfw.replace("Virginia Commonwealth","VCU")
dfw=dfw.replace("Southern Mississippi","Southern Miss")
dfw=dfw.replace("NC State","N.C. State")
te=set(dfw.Team.tolist())
sr={}

    
df['team']=df['team'].str.replace(" St."," State")
for row in dfw.itertuples():
    if float(row.Year) not in sr:
        sr[float(row.Year)]={}
    sr[float(row.Year)][str(row.Team)]=float(row.TY)
    
for row in df.itertuples():
    if row.team in sr[float(row.season)]:
        df.at[row.Index,'alarge']=sr[float(row.season)][row.team]
    else:
        df.at[row.Index,'alarge']=0
df.to_csv("barts.csv")

# %%
from bs4 import BeautifulSoup
arr=[]
import numpy as np
import pandas as pd
import requests
seasons={"2008":["20071105","20080316"],"2009":["20081110","20090310"],"2010":["20091109","20100309"],"2011":["20101108","20110313"],"2012":["20111107","20120311"],"2013":["20121109","20130317"],"2014":["20131108","20140316"],"2015":["20141114","20150315"],"2016":["20151113","20160313"],"2017":["20161111","20170312"],"2018":["20171110","20180311"],"2019":["20181106","20190317"],"2021":["20201125","20210314"],"2022":["20211109","20220313"],"2023":["20221107","20230312"],"2024":["20231106","20240317"]}
az=[]
for s in seasons:
    s=str(s)
    url="https://barttorvik.com/trank.php?begin="+str(seasons[s][0])+"&end="+str(seasons[s][1])+"&conlimit=All&year="+str(s)+"&top=0&hteam=&quad=5&rpi="
    html=requests.get(url).text
    print(s)
    soup=BeautifulSoup(html)
    table=soup.find_all("table")[0]
    rks={}
    for tr in table.find_all("tr"):
        if "seedrow" in str(tr):
            team=tr.find_all("td")[1].text
            team=team.split("\xa0")[0]
            team=team.replace("amp;","")
            rks[team]=float(tr.find_all("td")[0].text)
    
    for tr in table.find_all("tr"):
        
        if "seedrow" in str(tr):
            tds=tr.find_all("td")
            row=[]
            row.append(float(s)-1)
            res=tds[4].find("a")
            res=str(res)
            wins=res.split("Wins:&lt;/b&gt;")[1]
            wins=wins.replace(", &lt;br/&gt;&lt;b&gt;","")
            wins=wins.split("Losses&lt;/b&gt;:")[0]
            wins=wins.split(">")[0]
            
            losses=res.split("Losses&lt;/b&gt;:")[1]
            losses=losses.replace(', "',"")
            wins=wins.split(">")[0]
            wins=wins.replace("&lt;br/&gt;&lt;b&gt;","")
            losses=losses.replace("&lt;br/&gt;&lt;b&gt;","")
            if ' ">' in str(wins):
                wins=wins.split(' ">')[0]
            if ' ">' in str(losses):
                losses=losses.split(' ">')[0]
            q1w=0
            q1l=0
            q2w=0
            q2l=0
            q3w=0
            q3l=0
            hw=0
            hl=0
            aw=0
            al=0
            nw=0
            netw=[]
            netl=[]
            nl=0
            q4w=0
            q4l=0
            if wins!=' ' and wins!='':
                
                
                for w in wins.split(","):
                    wz=w
                    w=w.replace("amp;","")
                    w=w.rstrip()
                    w=w.lstrip()
                    t=w.replace("v. ","")
                    t=t.replace(" @","")
                    t=t.replace("@ ","")
                    if ">" in t:
                        t=t.split(">")[0]
                    if ">" in w:
                        w=w.split(">")[0]
                    netw.append(rks[t])
                    if "@" in str(w):
                        aw+=1
                    if ("@ ") in str(w):
                        w=w.replace("@ ","")
                        if rks[w]<76:
                            q1w+=1
                        elif rks[w]<136:
                            q2w+=1
                        elif rks[w]<241:
                            q3w+=1
                        else:
                            q4w+=1
                    if "@" not in str(wz) and "v." not in str(w):
                        hw+=1
                        if rks[w]<31:
                            q1w+=1
                        elif rks[w]<76:
                            q2w+=1
                        elif rks[w]<161:
                            q3w+=1
                        else:
                            q4w+=1
                    if "v." in str(w):
                        nw+=1
                        w=w.replace("v. ","")
                        if rks[w]<51:
                            q1w+=1
                        elif rks[w]<101:
                            q2w+=1
                        elif rks[w]<201:
                            q3w+=1
                        else:
                            q4w+=1
            if losses!=' ' and losses!='':
                for w in losses.split(","):
                    wz=w
                    w=w.replace("amp;","")
                    w=w.rstrip()
                    w=w.lstrip()
                    t=w.replace("v. ","")
                    t=t.replace(" @","")
                    t=t.replace("@ ","")
                    if ">" in w:
                        w=w.split(">")[0]
                    if ">" in t:
                        t=t.split(">")[0]
                    netl.append(rks[t])
                    if "@" in str(w):
                        al+=1
                        if ("@") in str(w):
                            w=w.replace("@ ","")
                        if rks[w]<76:
                            q1l+=1
                        elif rks[w]<136:
                            q2l+=1
                        elif rks[w]<241:
                            q3l+=1
                        else:
                            q4l+=1
                    if "@" not in str(wz) and "v." not in str(w):
                        hl+=1
                        if (" @ ") in str(w):
                            w=w.replace("   ","")
                        if rks[w]<31:
                            q1l+=1
                        elif rks[w]<76:
                            q2l+=1
                        elif rks[w]<161:
                            q3l+=1
                        else:
                            q4l+=1
                    if "v." in str(w):
                        nl+=1
                        if ("v. ") in str(w):
                            w=w.replace("v. ","")
                        if rks[w]<51:
                            q1l+=1
                        elif rks[w]<101:
                            q2l+=1
                        elif rks[w]<201:
                            q3l+=1
                        else:
                            q4l+=1
            for i in range(0,len(tds)):
                if i==4:
                    y=tds[i].find("a").text
                    x=tds[i].find("span").text
                    row.append(y)
                    row.append(x)
                else:
                    row.append(tds[i].text)
            
            row.append(q1w)
            row.append(q2w)
            row.append(q3w)
            row.append(q4w)
            row.append(q1l)
            row.append(q2l)
            row.append(q3l)
            row.append(q4l)
            row.append(hw)
            row.append(hl)
            row.append(aw)
            row.append(al)
            row.append(nw)
            row.append(nl)
            row.append(np.mean(netw))
            row.append(np.mean(netl))
            arr.append(row)
# Out:
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2021
# 2022
# 2023
# 2024

# %%
df=pd.DataFrame(arr,columns=['season','rk','team','conf','G','Rec',"CREC","ADJOE","ADJDE","BARTHAG","EFG","EFGD","TOR","TORD","ORB","DRB","FTR","FTRD","2P","2PD","3P","3PD","3PR","3PRD","ADJT","WAB",'q1w','q2w','q3w','q4w','q1l','q2l','q3l','q4l','hw','hl','aw','al','nw','nl','netw','netl'])

# %%
df
# Out:
#       Unnamed: 0  season   rk                               team  conf   G  \
# 0              0  2007.0    1            Kansas   1 seed, CHAMPS  29.0  33
# 1              1  2007.0    2           Memphis   1 seed, Finals   1.0  34
# 2              2  2007.0    3          UCLA   1 seed, Final Four  32.0  33
# 3              3  2007.0    4  Wisconsin   3 seed, Sweet Sixteen  21.0  33
# 4              4  2007.0    5                 Duke   2 seed, R32  11.0  32
# ...          ...     ...  ...                                ...   ...  ..
# 5602        5602  2023.0  358                          Stonehill  10.0  30
# 5603        5603  2023.0  359                      Saint Francis  10.0  28
# 5604        5604  2023.0  360                            IU Indy  35.0  29
# 5605        5605  2023.0  361                         Coppin St.   5.0  29
# 5606        5606  2023.0  362             Mississippi Valley St.   7.0  31
#
# ...

# %%
a=pd.DataFrame(arr)
a=a.head(1)
a[34]+a[36]+a[38]
# Out:
# 0    33
# dtype: int64

# %%
wins
# Out:
# ' '

# %%
q=pd.DataFrame(arr)
q
# Out:
#          0    1                                  2     3   4     5     6   \
# 0    2007.0    1            Kansas   1 seed, CHAMPS   B12  33  30–3  13–3
# 1    2007.0    2           Memphis   1 seed, Finals  CUSA  34  33–1  16–0
# 2    2007.0    3          UCLA   1 seed, Final Four   P10  33  30–3  16–2
# 3    2007.0    4  Wisconsin   3 seed, Sweet Sixteen   B10  33  29–4  16–2
# 4    2007.0    5                 Duke   2 seed, R32   ACC  32  27–5  13–3
# ..      ...  ...                                ...   ...  ..   ...   ...
# 336  2007.0  337                         Alcorn St.  SWAC  29  6–23  6–12
# 337  2007.0  338                      Grambling St.  SWAC  24  7–17  7–11
# 338  2007.0  339             North Carolina Central   ind  26  3–23   0–0
# 339  2007.0  340             Maryland Eastern Shore  MEAC  32  4–28  2–14
# 340  2007.0  341                               NJIT   ind  29  0–29   0–0
#
#           7         8         9   ... 32 33  34 35  36 37 38 39         40  \
# ...

# %%
len(q)
# Out:
# 341

# %%
q=pd.DataFrame(arr)
len(set(q[41].tolist()))
# Out:
# 1

# %%
import pandas as pd
pd.DataFrame(arr)

# %%
tr.find_all("th")

# %%
tr.find_all("th")

# %%
import scrapetube
import requests
from bs4 import BeautifulSoup
tmichaels="UCBG8zTGBDIDThADSqXrmqvQ"
dailyshow="UCwWhs_6x42TyRM4Wstoq8HA"
saturdaynightlive="UCqFzWxSCi39LnW1JKFR3efg"
kl='UCqFzWxSCi39LnW1JKFR3efg'
videos = scrapetube.get_channel(saturdaynightlive) #channel ID
u=0
import sys
for video in videos:
    if u<30:
        r = requests.get("https://www.youtube.com/oembed?url=youtube.com/watch?v="+str(video['videoId'])+"&format=json")
        r=r.json()
        title=r['title']
        title = title.replace("<title>","")
        title = title.replace("</title>","")
        print(video['videoId'],title)
        u+=1
    else:
        sys.exit(0)
# Out:
# IqdsIqYYXo4 Behind the Sketch: Gladiator II: The Musical - SNL
# BGW2CQK8VRI Weekend Update ft. Kenan Thompson and Mikey Day - SNL
# TuJnblwWLIs Pip - SNL
# 1sJXReaYgh8 Birthday at Friendly's - SNL
# vjbInjYp2ew Lady Gaga: Killah (Live) - SNL
# -xzXSPAGNwY No More Slay - SNL
# FPAa7VpOvwU Little Red Glasses - SNL
# DkJ221t0h5Y Weekend Update: Lord Gaga on His Unwavering Support for His Wife Lady Gaga - SNL
# ExNnHxMXJrs Lady Gaga: Abracadabra (Live) - SNL
# Rl_Y6MV_-so Weekend Update: Heterosexual Man Sues Starbucks for Discrimination, Scientists Create "Woolly Mouse"
# -mPL3MNCt1A Weekend Update: Kendrick Perkins on the 2025 NBA Playoffs - SNL
# QiqmoazqpgY Weekend Update: Trump Causes Tariff Confusion, Elon Musk's SpaceX Starship Explodes - SNL
# xu28o7TF8IE A Long Goodbye - SNL
# 6khBHQ67kSU Funeral Home - SNL
# 8LmvhzUVSkk Mascara Commercial - SNL
# GFH7tINxGng Wonderful Tonight - SNL
# 3JoK3nfHruQ Lady Gaga Monologue - SNL
# ...

# %%
sp='file.mp4'
url='https://www.youtube.com/watch?v=CUpOMSJ1MdU '
proxy={
    "http":"socks5://"
}
from pytubefix import YouTube
from pytubefix.cli import on_progress

pot='MnTKaADeNLFYqMpQ5uEvyRzntktGrx3D8hq5SkGhjb2jtflnAV4NLEsX4saSEchQXdzmxQvPDTMAtEoJjQCgC7gl4i-K5r5FgH6AijHio-jT6Skt82IDQOBdJsZrOodstODDwyUc5riZELsF3ukDtenpyMSK7Q=='
yt = YouTube(url, on_progress_callback=on_progress,use_po_token=True)
print(yt.title)

ys = yt.streams.get_highest_resolution()
ys.download()
# Out:
# You can use the tool: https://github.com/YunzheZJU/youtube-po-token-generator, to get the token
# Enter with your visitorData:
# Enter with your po_token:
# Elon Musk Cold Open - SNL
#  ↳ |███████████████████████████████████████████████████████| 100.0%
# '/kaggle/working/Elon Musk Cold Open - SNL.mp4'
